# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding="latin-1")
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
selected_columns = data[['Y2017', 'Area']]
area_sum_2017 = selected_columns.groupby('Area')['Y2017'].sum()
area_with_highest_sum = area_sum_2017.idxmax()

# The 'area_with_highest_sum' variable now contains the area with the highest sum in 'Y2017'
print("Area with the highest sum in Y2017:", area_with_highest_sum)
# Out:
# Area with the highest sum in Y2017: Nigeria

# %%
element_groupby = data.groupby('Element')['Y2017'].sum()
element_groupby
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
processing_2017 = element_groupby.loc['Processing']
processing_2017
# Out:
# 292836.0

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
protein_madagascar = data[(data['Area'] == 'Madagascar') & (data['Element'] == "Protein supply quantity (g/capita/day)")]
madagascar_2015 = 'Y2015'
 #total protein supplies made in the year 2015 in madagascar
total_protein_madagascar_2015 = protein_madagascar[madagascar_2015].sum(). round(2)
total_protein_madagascar_2015
# Out:
# 173.05

# %%
#What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?
column_mean = data['Y2017'].mean()
rounded_number = round(column_mean, 2)

print(rounded_number)
# Out:
# 140.92

# %%
column_std = data['Y2017'].std()
rounded_number = round(column_std, 2)

print(rounded_number)
# Out:
# 1671.86

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
missing_values = data['Y2014'].isna().sum()
number_of_rows = len(data)
percentage = (missing_values / number_of_rows) * 100

print(f"Percentage of missing data in '{'Y2014'}': {percentage:.2f}%")
# Out:
# Percentage of missing data in 'Y2014': 2.61%

# %%
missing_values
# Out:
# 1589

# %%
selected_columns = ['Y2017', 'Area']
data_selected = data[selected_columns]
area_groupby = data_selected.groupby('Area')['Y2017'].sum()
area_groupby
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
seventh_lowest_sum = area_groupby.nsmallest(7).index[-1]
seventh_lowest_sum
# Out:
# 'Guinea-Bissau'

# %%
unique_countries_sum = data['Area'].nunique()
unique_countries_sum
# Out:
# 49

# %%
#Which year had the least correlation with ‘Element Code’?
import seaborn as sns
sns.heatmap(data.corr(), vmin=-1, vmax=1,annot=True,cmap="RdBu")
# Out:
# C:\Users\deji\AppData\Local\Temp\ipykernel_28632\3114060284.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), vmin=-1, vmax=1,annot=True,cmap="RdBu")
# <Axes: >

# %% [markdown]
# AREA CODE HAD THE LEAST CORRELATION

# %%
element_groupby= data.groupby('Element').sum()
element_groupby
# Out:
# C:\Users\deji\AppData\Local\Temp\ipykernel_28632\1342268612.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   element_groupby= data.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
stock_variation = data[data['Element'] == 'Stock Variation']
stock_variation
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 13             4   Algeria       2905  Cereals - Excluding Beer          5072
# 29             4   Algeria       2511        Wheat and products          5072
# 45             4   Algeria       2805         Rice and products          5072
# 60             4   Algeria       2513       Barley and products          5072
# 75             4   Algeria       2514        Maize and products          5072
# ...          ...       ...        ...                       ...           ...
# 60842        181  Zimbabwe       2763              Pelagic Fish          5072
# 60853        181  Zimbabwe       2764        Marine Fish, Other          5072
# 60914        181  Zimbabwe       2928             Miscellaneous          5072
# 60924        181  Zimbabwe       2680               Infant food          5072
# 60934        181  Zimbabwe       2899             Miscellaneous          5072
#
# ...

# %%
sum_per_year = stock_variation.drop(columns=['Element', 'Area', 'Area Code', 'Item Code', 'Item','Unit','Element Code']).sum()
year_with_highest_stock_variation = sum_per_year.idxmax()
year_with_highest_stock_variation
# Out:
# 'Y2014'

# %%
sum_of_Wine_produced = data.groupby("Item")['Y2015', 'Y2018'].sum()
sum_of_Wine_produced
# Out:
# C:\Users\deji\AppData\Local\Temp\ipykernel_28632\1833103073.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_of_Wine_produced = data.groupby("Item")['Y2015', 'Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# Y2015:4251.81
# Y2018:4039.32

# %% [markdown]
# I DIDN'T GET THE CHANCE TO DO MY QUIZ BECAUSE OF TECHNICAL ISSUES AND I WAS GIVEN ZERO SO I AM ANSWERING THE OTHER QUESTIONS HERE

# %%
#Which of these python data structures is unorderly?
#ANSWER:set

# %%
#Given the following numpy array 

#array  = ([[94, 89, 63],[93, 92, 48],[92, 94, 56]])

#How would you select  the elements in bold and italics from the array?
#ANSWER:array[:2,1:]

# %%
#Given the following python code, what would the output of the code give?

#my_tuppy = (1,2,5,8)

#my_tuppy[2] = 6
#ANSWER:Type Error

# %%
#Which of the following dataframe methods can be used to access elements across rows and columns?
#ANSWER:df.iloc()

# %%
#How would you check for the number of rows and columns in a pandas DataFrame named df?
#ANSWERS:df.shape

# %%
#A pandas Dataframe with dimensions (100,3) has how many features and observations?
#ANSWER:3 features and 100observations

# %%
#Which of the following is a python inbuilt module?
#ANSWER:math
